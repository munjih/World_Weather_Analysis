# %%
# Import the dependencies.
import csv
import pandas as pd
import numpy as np
import requests
import time
import gmaps

# Import the API key.
from config import gmap_api_key

# Configure gmaps to use your Google API key.
gmaps.configure(api_key=gmap_api_key)

# %%
# Open the CSV created in part two into a DataFrame.
vacation_sites_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
vacation_sites_df
# Out:
#      City_ID             City Country Current Description  Max Temp    Lat  \
# 0          4  Bambous Virieux      MU          few clouds     84.20 -20.34
# 1          5          La Joya      MX           clear sky     67.37  18.67
# 2          7             Chuy      UY           clear sky     58.26 -33.70
# 3          9             Bela      IN       broken clouds     73.80  25.93
# 4         10        Terrasini      IT           clear sky     51.01  38.15
# ..       ...              ...     ...                 ...       ...    ...
# 249      556       Nouadhibou      MR           clear sky     62.60  20.93
# 250      560         Narrabri      AU       broken clouds     87.01 -30.32
# 251      561            Akyab      MM           clear sky     77.97  20.15
# 252      563             Tura      IN           clear sky     89.31  25.52
# 253      565           Noumea      NC     overcast clouds     86.00 -22.28
#
#         Lng                Hotel Name
# 0     57.76            Casa Tia Villa
# 1    -99.47         HOTEL BUGAMBILIAS
# 2    -53.46         Nuevo Hotel Plaza
# 3     81.98           Siddharth Hotel
# 4     13.08         Florio Park Hotel
# ..      ...                       ...
# 249  -17.03                 El Medina
# 250  149.78          Crossroads Hotel
# 251   92.90              Hotel Memory
# 252   90.22  Hotel RIKMAN Continental
# 253  166.46            Hôtel Le Lagon
#
# [254 rows x 8 columns]

# %%
# Dataframe for Flinders
flinders_df = vacation_sites_df.loc[vacation_sites_df["City"] == "Flinders"]
flinders_df
# Out:
#     City_ID      City Country Current Description  Max Temp    Lat     Lng  \
# 19       38  Flinders      AU     overcast clouds     73.99 -34.58  150.86
#
#                                  Hotel Name
# 19  Shellharbour Resort & Conference Centre

# %%
# Dataframe for Emerald
emerald_df = vacation_sites_df.loc[vacation_sites_df["City"] == "Emerald"]
emerald_df
# Out:
#     City_ID     City Country Current Description  Max Temp    Lat     Lng  \
# 50      102  Emerald      AU       broken clouds      88.0 -23.53  148.17
#
#            Hotel Name
# 50  The Irish Village

# %%
# Dataframe for Mareeba
mareeba_df = vacation_sites_df.loc[vacation_sites_df["City"] == "Mareeba"]
mareeba_df
# Out:
#      City_ID     City Country          Current Description  Max Temp   Lat  \
# 161      340  Mareeba      AU  light intensity shower rain      81.0 -17.0
#
#         Lng                   Hotel Name
# 161  145.43  Trinity Plains Tourist Park

# %%
# Dataframe for Codrington
codrington_df = vacation_sites_df.loc[vacation_sites_df["City"] == "Codrington"]
codrington_df
# Out:
#      City_ID        City Country Current Description  Max Temp    Lat     Lng  \
# 114      237  Codrington      AU    scattered clouds     58.37 -38.27  141.97
#
#                                Hotel Name
# 114  Codrington Gardens Bed And Breakfast

# %%
# Latitude, longitude pairs for the four cities
flinders = (float(flinders_df["Lat"]), float(flinders_df["Lng"]))
emerald = (float(emerald_df["Lat"]), float(emerald_df["Lng"]))
mareeba = (float(mareeba_df["Lat"]), float(mareeba_df["Lng"]))
codrington = (float(codrington_df["Lat"]), float(codrington_df["Lng"]))

# %%
# Merge the dataframes
vacation_itinerary_df = flinders_df.append(emerald_df).append(mareeba_df).append(codrington_df)
vacation_itinerary_df
# Out:
#      City_ID        City Country          Current Description  Max Temp  \
# 19        38    Flinders      AU              overcast clouds     73.99
# 50       102     Emerald      AU                broken clouds     88.00
# 161      340     Mareeba      AU  light intensity shower rain     81.00
# 114      237  Codrington      AU             scattered clouds     58.37
#
#        Lat     Lng                               Hotel Name
# 19  -34.58  150.86  Shellharbour Resort & Conference Centre
# 50  -23.53  148.17                        The Irish Village
# 161 -17.00  145.43              Trinity Plains Tourist Park
# 114 -38.27  141.97     Codrington Gardens Bed And Breakfast

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in vacation_itinerary_df.iterrows()]

# %%
# Directions layer map
fig = gmaps.figure()
itinerary_layer = gmaps.directions_layer(flinders, codrington, waypoints=[emerald, mareeba], travel_mode="DRIVING")
fig.add_layer(itinerary_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = vacation_itinerary_df[["Lat", "Lng"]]
max_temp = vacation_itinerary_df["Max Temp"]

fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
