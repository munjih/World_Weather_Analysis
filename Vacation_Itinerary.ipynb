# %%
# Import the dependencies.
import csv
import pandas as pd
import numpy as np
import requests
import time
import gmaps

# Import the API key.
from config import gmap_api_key

# %%
# Open the CSV created in part two into a DataFrame.
vacation_sites_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
vacation_sites_df.head()
# Out:
#    City_ID             City Country Current Description  Max Temp    Lat  \
# 0       18  Haines Junction      CA          light snow     19.83  60.75
# 1       92         Khatanga      RU          light snow      6.55  71.97
# 2      123       Zabaykalsk      RU          light snow     13.64  49.63
# 3      130           Nayoro      JP          light snow     20.71  44.35
# 4      152   Severo-Kurilsk      RU          light snow     17.06  50.68
#
#       Lng                Hotel Name
# 0 -137.51              Parkside Inn
# 1  102.50  Gostinitsa "Zapolyar'ye"
# 2  117.32               Gk Imperiya
# 3  142.46                       大雪荘
# 4  156.12                  Kak Doma
