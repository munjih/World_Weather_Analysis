# %%
# Import the dependencies.
import csv
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=11242e56d56985b898a6296a6be49234

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 617

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1

# Perform an API call with the OpenWeatherMap
for city in cities:
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Retrieve 3hr rain data, if not raining, add 0 inches
        try:
           city_rain = city_weather["rain"]["3h"]
        except:
           city_rain = 0
        # Retrieve 3hr snow data, if not snowing, add 0 inches
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Parse out weather description from array
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow
                          })
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | great falls
# Processing Record 2 | hithadhoo
# Processing Record 3 | necochea
# Processing Record 4 | kodiak
# Processing Record 5 | bambous virieux
# Processing Record 6 | la joya
# Processing Record 7 | busselton
# Processing Record 8 | chuy
# Processing Record 9 | norman wells
# Processing Record 10 | bela
# Processing Record 11 | terrasini
# Processing Record 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 | amahai
# Processing Record 14 | kahului
# Processing Record 15 | qaanaaq
# Processing Record 16 | mataura
# Processing Record 17 | ushuaia
# Processing Record 18 | cabra
# Processing Record 19 | inhambane
# Processing Record 20 | haines junction
# Processing Record 21 | alta floresta
# Processing Record 22 | margate
# Processing Record 23 | east london
# Processing Record 24 | ahipara
# Processing Record 25 | hobart
# Processing Record 26 | tasiilaq
# ...

# %%
len(city_data)
# Out:
# 566

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0      Great Falls      US  2020-02-21 07:12:14  47.50 -111.30     41.00
# 1        Hithadhoo      MV  2020-02-21 07:12:14  -0.60   73.08     84.24
# 2         Necochea      AR  2020-02-21 07:12:14 -38.55  -58.74     57.99
# 3           Kodiak      US  2020-02-21 07:12:14  57.79 -152.41     32.00
# 4  Bambous Virieux      MU  2020-02-21 07:12:14 -20.34   57.76     84.20
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        23          75       25.28       broken clouds
# 1        77           7       14.45          light rain
# 2        64          62       21.99          light rain
# 3        74          90       10.29     overcast clouds
# 4        58          20       11.41          few clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.44                       0.0
# ...

# %%
#city_data_df["Rain inches (last 3 hrs)"]= city_data_df["Rain inches (last 3 hrs)"].map('{:,.3f}'.format)

# %%
city_data_df
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 0        Great Falls      US  2020-02-21 07:12:14  47.50 -111.30     41.00
# 1          Hithadhoo      MV  2020-02-21 07:12:14  -0.60   73.08     84.24
# 2           Necochea      AR  2020-02-21 07:12:14 -38.55  -58.74     57.99
# 3             Kodiak      US  2020-02-21 07:12:14  57.79 -152.41     32.00
# 4    Bambous Virieux      MU  2020-02-21 07:12:14 -20.34   57.76     84.20
# ..               ...     ...                  ...    ...     ...       ...
# 561            Akyab      MM  2020-02-21 07:14:44  20.15   92.90     77.97
# 562          Houston      US  2020-02-21 07:10:38  29.76  -95.36     46.00
# 563             Tura      IN  2020-02-21 07:14:45  25.52   90.22     89.31
# 564         Hamilton      US  2020-02-21 07:10:55  39.18  -84.53     21.20
# 565           Noumea      NC  2020-02-21 07:14:45 -22.28  166.46     86.00
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.dtypes
# Out:
# City                         object
# Country                      object
# Date                         object
# Lat                         float64
# Lng                         float64
# Max Temp                    float64
# Humidity                      int64
# Cloudiness                    int64
# Wind Speed                  float64
# Current Description          object
# Rain inches (last 3 hrs)    float64
# Snow inches (last 3 hrs)    float64
# dtype: object

# %%
# Count cities that have recorded rainfall or snow
city_rain_count = (city_data_df["Rain inches (last 3 hrs)"] != 0).sum()
city_snow_count = (city_data_df["Snow inches (last 3 hrs)"] != 0).sum()
city_rain_or_snow = city_rain_count + city_snow_count
city_rain_or_snow
# Out:
# 81
